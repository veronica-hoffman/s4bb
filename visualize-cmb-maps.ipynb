# %%
import healpy as hp
import matplotlib.pyplot as plt

filename = "/global/cfs/cdirs/cmbs4/chile_optimization/simulations/phase2/input_sky/cmb_c4/cmbs4_cmb_c4_uKCMB_SAT_f220_nside512.fits"
map_data = hp.read_map(filename)

hp.mollview(map_data, 
           title="CMB temperature map (280 GHz)", 
           unit="μK_CMB",
           cmap='RdYlBu_r')

hp.graticule()
plt.show()

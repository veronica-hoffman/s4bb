# %%
import matplotlib.pyplot as plt
import h5py
import numpy as np
import pandas as pd
import phase2_common as ph2
from s4bb.spectra import XSpec, CalcSpec_namaster

# %%
params_withpbs = np.load('mlsearch/ph2_mlsearch_f1_y20_n3_full_withpbs_diag0_V.npy').T
df_withpbs = pd.DataFrame(params_withpbs, columns = ['status', 'fval', 'r', 'A_d', 'alpha_d', 'beta_d', 'A_s', 'alpha_s', 'beta_s', 'epsilon', 'Delta_d', 'Delta_s'])
df_withpbs.describe()
# Out:
#        status        fval           r         A_d     alpha_d      beta_d  \
# count   100.0  100.000000  100.000000  100.000000  100.000000  100.000000
# mean      0.0  381.714271    0.000166   14.227285   -0.802280    1.650214
# std       0.0   26.224790    0.000338    0.553585    0.042979    0.006661
# min       0.0  324.281333   -0.000697   13.695381   -0.868954    1.634985
# 25%       0.0  363.735795   -0.000061   13.732275   -0.844251    1.644909
# 50%       0.0  379.179260    0.000143   13.746824   -0.782347    1.649566
# 75%       0.0  400.976105    0.000389   14.813861   -0.769109    1.655580
# max       0.0  446.847820    0.001115   15.140416   -0.683970    1.663871
#
#               A_s     alpha_s      beta_s     epsilon     Delta_d     Delta_s
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     1.066390   -0.958628   -3.092062    0.023610    0.999245    0.999204
# ...

# %%
params = np.load('mlsearch_bandpass_fts/ph2_mlsearch_f1_y20_n3_diag0_full_withpbs.npy').T
df = pd.DataFrame(params, columns = ['status', 'fval', 'r', 'A_d', 'alpha_d', 'beta_d', 'A_s', 'alpha_s', 'beta_s', 'epsilon', 'Delta_d', 'Delta_s', 'freq_shift'])
df.describe()
# Out:
#        status        fval           r         A_d     alpha_d      beta_d  \
# count   100.0  100.000000  100.000000  100.000000  100.000000  100.000000
# mean      0.0  381.714271    0.000166   14.227285   -0.802280    1.650214
# std       0.0   26.224790    0.000338    0.553585    0.042979    0.006661
# min       0.0  324.281333   -0.000697   13.695381   -0.868954    1.634985
# 25%       0.0  363.735795   -0.000061   13.732275   -0.844251    1.644909
# 50%       0.0  379.179260    0.000143   13.746824   -0.782347    1.649566
# 75%       0.0  400.976105    0.000389   14.813861   -0.769109    1.655580
# max       0.0  446.847820    0.001115   15.140416   -0.683970    1.663871
#
#               A_s     alpha_s      beta_s     epsilon     Delta_d     Delta_s  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     1.066390   -0.958628   -3.092062    0.023610    0.999245    0.999204
# ...

# %%
params = np.load('mlsearch_bandpass_ghz/ph2_mlsearch_f1_y20_n3_diag0_full_withpbs_uniform_+2.0GHz.npy').T
df = pd.DataFrame(params, columns = ['status', 'fval', 'r', 'A_d', 'alpha_d', 'beta_d', 'A_s', 'alpha_s', 'beta_s', 'epsilon', 'Delta_d', 'Delta_s'])
df.describe()
# Out:
#        status        fval           r         A_d     alpha_d      beta_d  \
# count   100.0  100.000000  100.000000  100.000000  100.000000  100.000000
# mean      0.0  394.564665    0.000218   13.700292   -0.823244    1.655147
# std       0.0   41.654320    0.000341    0.011610    0.026839    0.006877
# min       0.0  327.752755   -0.000720   13.661600   -0.888556    1.639554
# 25%       0.0  369.769329   -0.000012   13.697310   -0.831314    1.649512
# 50%       0.0  388.770685    0.000196   13.701438   -0.824933    1.654586
# 75%       0.0  410.963607    0.000441   13.705968   -0.819796    1.660708
# max       0.0  590.093224    0.001144   13.753492   -0.690618    1.674681
#
#               A_s     alpha_s      beta_s     epsilon     Delta_d     Delta_s
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     1.775529   -0.955941   -3.276987    0.022000    0.999232    0.999069
# ...

# %%
params = np.load('mlsearch_bandpass_fts/ph2_mlsearch_f1_y20_n3_diag0_full_withpbs_2GHz.npy').T
df = pd.DataFrame(params, columns = ['status', 'fval', 'r', 'A_d', 'alpha_d', 'beta_d', 'A_s', 'alpha_s', 'beta_s', 'epsilon', 'Delta_d', 'Delta_s', 'freq_shift'])
df.describe()
# Out:
#        status        fval           r         A_d     alpha_d      beta_d  \
# count   100.0  100.000000  100.000000  100.000000  100.000000  100.000000
# mean      0.0  392.048378    0.000208   13.700449   -0.822321    1.654952
# std       0.0   39.581233    0.000344    0.011065    0.020113    0.006722
# min       0.0  327.758281   -0.000659   13.649770   -0.840670    1.639595
# 25%       0.0  369.103944   -0.000013   13.697632   -0.830730    1.649623
# 50%       0.0  386.798942    0.000196   13.702000   -0.825210    1.654484
# 75%       0.0  407.185155    0.000441   13.706381   -0.819857    1.660301
# max       0.0  618.172984    0.001144   13.716695   -0.690731    1.674685
#
#               A_s     alpha_s      beta_s     epsilon     Delta_d     Delta_s  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     1.795400   -0.961025   -3.278514    0.021966    0.999222    0.999105
# ...

# %%
params = np.load('mlsearch_bandpass_ghz/ph2_mlsearch_f2_y20_n3_diag0_full_withpbs_uniform_+2.0GHz.npy').T
df = pd.DataFrame(params, columns = ['status', 'fval', 'r', 'A_d', 'alpha_d', 'beta_d', 'A_s', 'alpha_s', 'beta_s', 'epsilon', 'Delta_d', 'Delta_s'])
df.describe()
# Out:
#        status        fval           r         A_d     alpha_d      beta_d  \
# count   100.0  100.000000  100.000000  100.000000  100.000000  100.000000
# mean      0.0  392.285303    0.001795   59.506014   -0.506812    1.534447
# std       0.0   37.666786    0.000826    0.011970    0.007754    0.004290
# min       0.0  334.317236   -0.000136   59.422442   -0.545484    1.524554
# 25%       0.0  368.569575    0.001200   59.502655   -0.511472    1.531310
# 50%       0.0  386.507238    0.001883   59.505993   -0.506640    1.534540
# 75%       0.0  404.593727    0.002368   59.508804   -0.503200    1.537489
# max       0.0  585.064375    0.003819   59.582884   -0.476356    1.545287
#
#               A_s     alpha_s      beta_s     epsilon     Delta_d     Delta_s
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     2.292156   -0.963444   -3.240841    0.007251    0.998544    0.999734
# ...

# %%
params = np.load('mlsearch_bandpass_fts/ph2_mlsearch_f2_y20_n3_diag0_full_withpbs_2GHz.npy').T
df = pd.DataFrame(params, columns = ['status', 'fval', 'r', 'A_d', 'alpha_d', 'beta_d', 'A_s', 'alpha_s', 'beta_s', 'epsilon', 'Delta_d', 'Delta_s', 'freq_shift'])
df.describe()
# Out:
#        status        fval           r         A_d     alpha_d      beta_d  \
# count   100.0  100.000000  100.000000  100.000000  100.000000  100.000000
# mean      0.0  389.493895    0.001834   59.505544   -0.506050    1.534659
# std       0.0   28.239999    0.000844    0.008980    0.007492    0.004663
# min       0.0  334.325760   -0.000137   59.423182   -0.520182    1.525412
# 25%       0.0  368.570078    0.001226   59.503084   -0.511242    1.531310
# 50%       0.0  386.811224    0.001952   59.506202   -0.505978    1.534435
# 75%       0.0  407.223472    0.002404   59.508813   -0.501571    1.537428
# max       0.0  480.682550    0.003824   59.514727   -0.469662    1.557897
#
#               A_s     alpha_s      beta_s     epsilon     Delta_d     Delta_s  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     2.286746   -0.950475   -3.244158    0.008255    0.998545    0.999804
# ...

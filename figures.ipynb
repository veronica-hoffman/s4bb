# %%
import matplotlib.pyplot as plt
import h5py
import numpy as np
import pandas as pd
import phase2_common as ph2
from s4bb.spectra import XSpec, CalcSpec_namaster

# %%
with h5py.File('/global/cfs/cdirs/cmbs4/chile_optimization/analysis/cbischoff/phase2/spectra/phase2_spec_comb_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f1, \
     h5py.File('/global/homes/v/vhoffman/reproduce_colin_results/spectra/phase2_spec_comb_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f2:
    spec1 = XSpec.from_hdf5(f1)
    spec2 = XSpec.from_hdf5(f2)

ell_centers = 0.5 * (spec1.bins[0] + spec1.bins[1])

ps_mean1 = np.mean(spec1.spec, axis=2)
ps_mean2 = np.mean(spec2.spec, axis=2)

spec_names1 = spec1.str()
    
ell_centers = 0.5 * (spec1.bins[0] + spec1.bins[1])

ps_mean = np.mean(spec1.spec, axis=2)

spec_names = spec1.str()

plt.plot(ell_centers, ps_mean1[9], marker='o', linestyle='-', color='red', label='Bischoff')
plt.plot(ell_centers, ps_mean2[9], marker='s', linestyle='--', color='blue', label='Hoffman')
plt.xlabel(r'$\ell$')
plt.ylabel(r'$C_\ell$')
plt.title(r'HF-1$_B$ $\times$ HF-1$_B$', fontsize = 15)
plt.grid()
plt.legend()
plt.show()

# %%
with h5py.File('/global/homes/v/vhoffman/reproduce_colin_results/spectra/phase2_spec_comb_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f:
    spec = XSpec.from_hdf5(f)

ell_centers = 0.5 * (spec.bins[0] + spec.bins[1])

ps_mean = np.mean(spec.spec, axis=2)

spec_names = spec.str()

plt.plot(ell_centers, ps_mean[9]*10**3, color='blue')
plt.xlabel(r'Multipole moment, $\ell$', fontsize = 15)
plt.ylabel(r'Temperature Fluctuations μK^2', fontsize = 15)
plt.title(r'HF-1$_B$ $\times$ HF-1$_B$', fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid()
plt.show()
